# %%
# %matplotlib widget
import numpy as np
import pandas as pd
import geopandas as gpd

# %%
# read all csv files in the folder
# and merge them into one dataframe
# and save it as csv file

import pandas as pd
import os

# %%
os.listdir('./data')
# Out:
# ['us_patents', 'twitter', '.DS_Store', 'livejournal', 'mel']

# %%
data_dir = ['us_patents', 'twitter', 'livejournal', 'mel']
df = dict()
for d in data_dir:
    files = os.listdir('./data/' + d + '/')
    csv_files = [f for f in files if f[-3:] == 'csv']

    df[d] = pd.DataFrame()

    for f in csv_files:
        df[d] = df[d].append(pd.read_csv('./data/' + d + '/' + f))
# Out:
# /var/folders/mm/5vsgc5194kqf1xnmgq439jww0000gn/T/ipykernel_2184/3416025493.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df[d] = df[d].append(pd.read_csv('./data/' + d + '/' + f))
# /var/folders/mm/5vsgc5194kqf1xnmgq439jww0000gn/T/ipykernel_2184/3416025493.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df[d] = df[d].append(pd.read_csv('./data/' + d + '/' + f))
# /var/folders/mm/5vsgc5194kqf1xnmgq439jww0000gn/T/ipykernel_2184/3416025493.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df[d] = df[d].append(pd.read_csv('./data/' + d + '/' + f))
# ...

# %%
#sum all the duplicates in df['mel'] dataframe
df['mel'].sum()
# Out:
# signature    ABCDBECFABCDEBDFABCDBEDFABCDEFCGABCDEBFGABCDBC...
# count                                                  5483800
# dtype: object

# %%
# read all csv files and merge them into one dataframe
df = pd.DataFrame()
for f in csv_files:
    df = df.append(pd.read_csv('data/livejournal/' + f))
# Out:
# /var/folders/mm/5vsgc5194kqf1xnmgq439jww0000gn/T/ipykernel_2184/1527689212.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_csv('data/livejournal/' + f))
# /var/folders/mm/5vsgc5194kqf1xnmgq439jww0000gn/T/ipykernel_2184/1527689212.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_csv('data/livejournal/' + f))
# /var/folders/mm/5vsgc5194kqf1xnmgq439jww0000gn/T/ipykernel_2184/1527689212.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_csv('data/livejournal/' + f))
# ...

# %%
df.head()
# Out:
#   signature   count
# 0       ABC   67152
# 0     ABCDE  339014
# 1     ABCDB    2446
# 2     ABCAD    2446
# 3     ABCDA     128

# %%
# save the dataframe as csv file
df.to_csv('results/result.csv', index=False)

# %%
# !tree data
# Out:
# data
# ├── livejournal
# │   ├── 1000_3.csv
# │   ├── 1000_4.csv
# │   ├── 1000_5.csv
# │   ├── 100_3.csv
# │   ├── 100_4.csv
# │   ├── 100_5.csv
# │   ├── 100_6.csv
# │   ├── 100_7.csv
# │   ├── 500_3.csv
# │   ├── 500_4.csv
# │   └── 500_5.csv
# ├── mel
# │   ├── 1000_3.csv
# │   ├── 1000_4.csv
# │   ├── 1000_5.csv
# │   ├── 100_10.csv
# │   ├── 100_3.csv
# │   ├── 100_4.csv
# │   ├── 100_5.csv
# │   ├── 100_6.csv
# │   ├── 100_7.csv
# │   ├── 100_8.csv
# │   ├── 100_9.csv
# │   ├── 500_3.csv
# │   ├── 500_4.csv
# │   ├── 500_5.csv
# │   └── 500_6.csv
# ├── twitter
# │   ├── 1000_3.csv
# │   ├── 1000_4.csv
# │   ├── 1000_5.csv
# │   ├── 1000_6.csv
# │   ├── 1000_7.csv
# │   ├── 1000_8.csv
# │   ├── 100_3.csv
# │   ├── 100_4.csv
# │   ├── 100_5.csv
# │   ├── 100_6.csv
# │   ├── 100_7.csv
# │   ├── 100_8.csv
# │   ├── 100_9.csv
# │   ├── 500_3.csv
# │   ├── 500_4.csv
# │   ├── 500_5.csv
# │   ├── 500_6.csv
# │   ├── 500_7.csv
# │   └── 500_8.csv
# └── us_patents
# ...

# %%
gdf = gpd.read_file("lille_level5.geojson")

# %%
gdf.code.max()
# Out:
# '59670'

# %%
print(gdf.columns)
# Out:
# Index(['code', 'nom', 'geometry'], dtype='object')

# %%
gdf[gdf['NAME_4'] == 'Lille']
# Out:
#                GID_4 GID_0 COUNTRY    GID_1           NAME_1      GID_2  \
# 1649  FRA.7.2.5.10_1   FRA  France  FRA.7_1  Hauts-de-France  FRA.7.2_1
#
#      NAME_2        GID_3 NAME_3 NAME_4 VARNAME_4  TYPE_4 ENGTYPE_4 CC_4  \
# 1649   Nord  FRA.7.2.5_1  Lille  Lille        NA  Canton    Canton   NA
#
#                                                geometry
# 1649  MULTIPOLYGON (((2.97040 50.63950, 2.97440 50.6...

# %%
geodb.describe()
# Out:
#        GID_0  NAME_0                                           geometry
# count      1       1                                                  1
# unique     1       1                                                  1
# top      FRA  France  MULTIPOLYGON (((9.25763988 41.34902954, 9.2576...
# freq       1       1                                                  1

# %%
geodb.head(1).T
# Out:
#                                                           0
# GID_0                                                   FRA
# NAME_0                                               France
# geometry  MULTIPOLYGON (((9.25763988 41.34902954, 9.2576...

# %%
gpd.pd.unique(geodb['GID_0'])
# Out:
# array(['FRA'], dtype=object)

# %%
geodb.plot()
# Out:
# <Axes: >
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
type(geodb)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
dir(geodb)
# Out:
# ['GID_0',
#  'NAME_0',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__geo_interface__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
geodb['GID_0']
# Out:
# 0    FRA
# Name: GID_0, dtype: object

# %%
geodb.columns
# Out:
# Index(['GID_0', 'NAME_0', 'geometry'], dtype='object')

# %%
type(geodb.geometry)
# Out:
# geopandas.geoseries.GeoSeries

# %%
print(geodb.columns)
# Out:
# Index(['GID_0', 'NAME_0', 'geometry'], dtype='object')
